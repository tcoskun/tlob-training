# %% [markdown]
# # TensorFlow LSTM Model for Price Prediction

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.lstm_analyzer import LSTMAnalyzer

lstm_analyzer = LSTMAnalyzer()
print("Setup and Imports Done!")
# Out:
# Setup and Imports Done!

# %% [markdown]
# ## 2. Start Analysis

# %%
""" Tensorflow Analysis """
lstm_analyzer.start_analysis();
# Out:
# No GPU .
# Using device: /device:CPU:0
# Found 10 CSV files:
#   - 2025-08-12-AKBNK-10.csv
#   - 2025-08-14-AKBNK-10.csv
#   - 2025-08-15-AKBNK-10.csv
#   - 2025-08-18-AKBNK-10.csv
#   - 2025-08-20-AKBNK-10.csv
#   - 2025-08-21-AKBNK-10.csv
#   - 2025-08-22-AKBNK-10.csv
#   - 2025-08-25-AKBNK-10.csv
#   - 2025-08-26-AKBNK-10.csv
#   - 2025-08-27-AKBNK-10.csv
# Reading 2025-08-12-AKBNK-10.csv...
#   - Shape: (29405, 47)
# Reading 2025-08-14-AKBNK-10.csv...
#   - Shape: (29438, 47)
# Reading 2025-08-15-AKBNK-10.csv...
#   - Shape: (29426, 47)
# Reading 2025-08-18-AKBNK-10.csv...
#   - Shape: (29423, 47)
# Reading 2025-08-20-AKBNK-10.csv...
#   - Shape: (29422, 47)
# Reading 2025-08-21-AKBNK-10.csv...
#   - Shape: (29424, 47)
# Reading 2025-08-22-AKBNK-10.csv...
#   - Shape: (29429, 47)
# Reading 2025-08-25-AKBNK-10.csv...
#   - Shape: (29437, 47)
# Reading 2025-08-26-AKBNK-10.csv...
#   - Shape: (29399, 47)
# Reading 2025-08-27-AKBNK-10.csv...
#   - Shape: (29430, 47)
#
# Combined DataFrame shape: (294233, 47)
# DataFrame sorted by DateTime, final shape: (294233, 47)
#
# Selected Features: ['Depth Ratio', 'Last Price', 'Total Bid Volume', ' Total Ask Volume', 'Level 1 Bid Price', 'Level 1 Bid Volume', 'Level 1 Ask Price', 'Level 1 Ask Volume', 'Level 2 Bid Price', 'Level 2 Bid Volume', 'Level 2 Ask Price', 'Level 2 Ask Volume', 'Level 3 Bid Price', 'Level 3 Bid Volume', 'Level 3 Ask Price', 'Level 3 Ask Volume', 'Level 4 Bid Price', 'Level 4 Bid Volume', 'Level 4 Ask Price', 'Level 4 Ask Volume', 'Level 5 Bid Price', 'Level 5 Bid Volume', 'Level 5 Ask Price', 'Level 5 Ask Volume', 'midPrice']
# Target Column: midPrice
# /Users/tolgacoskun-mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Starting model training...
# Epoch 1/350
#  16/490 ━━━━━━━━━━━━━━━━━━━━ 28:21 4s/step - loss: 0.1020 - mean_absolute_percentage_error: 130.6245
